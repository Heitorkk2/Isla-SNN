# %% [markdown]
# # Isla-SNN: Interactive Chat Inference 🔋
#
# This notebook is used for evaluating the Fine-Tuned Chat model.
# It mounts your Google Drive, loads the instruction-tuned weights natively, and runs a streaming inference loop.

# %%
# !git clone https://github.com/Heitorkk2/Isla-SNN.git
# %cd Isla-SNN
# !pip install -q -e ".[dev]"

# %% [markdown]
# ## Auto-Cast Inference
# We enforce `autocast=bfloat16` during inference to match the training distributions. This prevents internal voltage/spike threshold drift.

# %%
chat_with_isla("What is the average lifespan of a Golden Retriever?")

# %%
chat_with_isla("Write a poem about the ocean.")
